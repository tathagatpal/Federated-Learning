# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import syft as sy
import copy
import numpy as np
import time
import math
from torch import Tensor
from typing import List, Optional
from torch.optim import Optimizer

import importlib
importlib.import_module('FLDataset')
from FLDataset import load_dataset, getActualImgs
from utils import averageModels

# %%
#Function to do updates according to Adam's Formula
def adam(params: List[Tensor],grads: List[Tensor],exp_avgs: List[Tensor],exp_avg_sqs: List[Tensor],
         max_exp_avg_sqs: List[Tensor],state_steps: List[int],*,beta1: float,beta2: float,lr: float,
         eps: float):
    
    for i, param in enumerate(params):

        grad = grads[i]
        exp_avg = exp_avgs[i]
        exp_avg_sq = exp_avg_sqs[i]
        step = state_steps[i]

        bias_correction1 = 1 - beta1 ** step
        bias_correction2 = 1 - beta2 ** step

        #Configuring the first and second moment running average coefficient
        exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
        exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
        
        denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)

        step_size = lr / bias_correction1

        param.addcdiv_(exp_avg, denom, value=-step_size)

#Creating Adam Optimizer which overrides the step function.
class Adam(Optimizer):

    #Constructor with 4 parameters: LR, Beta rate and epsilon
    def __init__(self, params, lr=1e-3, betas=(0.9, 0.999), eps=1e-7):

        defaults = dict(lr=lr, betas=betas, eps=eps)
        
        #Calling constructor of in-built PyTorch
        super(Adam, self).__init__(params, defaults)

    #THIS IS THE PART WHERE WE ARE IMPLEMENTING THE ADAM OPTIMIZER. 
    @torch.no_grad()
    def step(self):
        
        loss = None

        for group in self.param_groups:
            #Creating list to store various model parameters
            params_with_grad = []
            grads = []
            exp_avgs = []
            exp_avg_sqs = []
            max_exp_avg_sqs = []
            state_steps = []
            beta1, beta2 = group['betas']

            for p in group['params']:
                if p.grad is not None:
                    params_with_grad.append(p)
                    grads.append(p.grad)

                    state = self.state[p]
                    if len(state) == 0:
                        state['step'] = 0
                        #Gradient values' exponential moving average
                        state['exp_avg'] = torch.zeros_like(p, memory_format=torch.preserve_format)
                        
                        #Squared gradient values' exponential moving average
                        state['exp_avg_sq'] = torch.zeros_like(p, memory_format=torch.preserve_format)
                       
                    exp_avgs.append(state['exp_avg'])
                    exp_avg_sqs.append(state['exp_avg_sq'])

                    #Updating the number of steps for each param group
                    state['step'] += 1
                    
                    #Store and append the step after update
                    state_steps.append(state['step'])

            #Calling Adam's function to update parameters
            adam(params_with_grad, grads, exp_avgs,exp_avg_sqs,max_exp_avg_sqs,state_steps,
                   beta1=beta1,beta2=beta2,lr=group['lr'],eps=group['eps'])
            
        #return value of loss   
        return loss

# %%
#Class to define FL parameters
class Arguments():
    def __init__(self):
        self.images = 60000
        self.clients = 5
        self.rounds = 100
        self.epochs = 5
        self.local_batches = 128
        self.lr = 0.01
        self.C = 0.9
        self.drop_rate = 0.1
        self.torch_seed = 0
        self.log_interval = 100
        self.iid = 'iid'
        self.split_size = int(self.images / self.clients)
        self.samples = self.split_size / self.images 
        self.use_cuda = False
        self.save_model = False

args = Arguments()

use_cuda = args.use_cuda and torch.cuda.is_available()
device = torch.device("cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
## creating clients for FL

hook = sy.TorchHook(torch)
clients = []

for i in range(args.clients):
    clients.append({'hook': sy.VirtualWorker(hook, id="client{}".format(i+1))})

# %%
# Download FashionMNIST manually using 'wget' then uncompress the file
# !wget www.di.ens.fr/~lelarge/FashionMNIST.tar.gz
# !tar -zxvf FashionMNIST.tar.gz
# Out:
# --2021-12-09 02:54:50--  http://www.di.ens.fr/~lelarge/FashionMNIST.tar.gz
# Resolving www.di.ens.fr (www.di.ens.fr)... 129.199.99.14
# Connecting to www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.di.ens.fr/~lelarge/FashionMNIST.tar.gz [following]
# --2021-12-09 02:54:51--  https://www.di.ens.fr/~lelarge/FashionMNIST.tar.gz
# Connecting to www.di.ens.fr (www.di.ens.fr)|129.199.99.14|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-12-09 02:54:52 ERROR 404: Not Found.
#
# tar (child): FashionMNIST.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
global_train, global_test, train_group, test_group = load_dataset(args.clients, args.iid)

# %%
for inx, client in enumerate(clients):
    trainset_ind_list = list(train_group[inx])
    client['trainset'] = getActualImgs(global_train, trainset_ind_list, args.local_batches)
    client['testset'] = getActualImgs(global_test, list(test_group[inx]), args.local_batches)
    client['samples'] = len(trainset_ind_list) / args.images

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
global_test_dataset = datasets.FashionMNIST('./', train=False, download=True, transform=transform)
global_test_loader = DataLoader(global_test_dataset, batch_size=args.local_batches, shuffle=True)

global_train_dataset = datasets.FashionMNIST('./', train=True, download=True, transform=transform)
global_train_loader = DataLoader(global_train_dataset, batch_size=args.local_batches, shuffle=True)

# %%
## creating neural net structure using pytorch

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5, 1)
        self.conv2 = nn.Conv2d(20, 50, 5, 1)
        self.fc1 = nn.Linear(4*4*50, 500)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*50)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
## function to do updates during FL model rounds (calls step function)

def ClientUpdate(args, device, client):
    client['model'].train()
    client['model'].send(client['hook'])
    
    for epoch in range(1, args.epochs + 1):
        for batch_idx, (data, target) in enumerate(client['trainset']):
            data = data.send(client['hook'])
            target = target.send(client['hook'])
            
            data, target = data.to(device), target.to(device)
            client['optim'].zero_grad()
            output = client['model'](data)
            loss = F.nll_loss(output, target)
            loss.backward()
            client['optim'].step()
            
            if batch_idx % args.log_interval == 0:
                loss = loss.get() 
                print('Model {} Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    client['hook'].id,
                    epoch, batch_idx * args.local_batches, len(client['trainset']) * args.local_batches, 
                    100. * batch_idx / len(client['trainset']), loss))
                
    client['model'].get()

# %%
## prints values periodically on testing data
def test(args, model, device, test_loader, name, isPrint):

    model.eval()   
    test_losss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_losss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_losss /= len(test_loader.dataset)
    
    if isPrint:
        print('\nTest set: Average loss for {} model: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        name, test_losss, correct, len(test_loader.dataset),100. * correct / len(test_loader.dataset)))
        test_loss.append(test_losss)
        test_acc.append(correct/len(test_loader.dataset))
        
    else:
        train_loss.append(test_losss)
        train_acc.append(correct/len(test_loader.dataset))
   
        
    #return loss_list

# %%
torch.manual_seed(args.torch_seed)
global_model = Net()

train_loss = []
test_loss = []
train_acc = []
test_acc = []

for client in clients:
    torch.manual_seed(args.torch_seed)
    client['model'] = Net().to(device)
    client['optim'] = Adam(client['model'].parameters())
    
for fed_round in range(args.rounds):
    
    # number of selected clients
    m = int(max(args.C * args.clients, 1))

    # Selected devices
    np.random.seed(fed_round)
    selected_clients_inds = np.random.choice(range(len(clients)), m, replace=False)
    selected_clients = [clients[i] for i in selected_clients_inds]
    
    # Active devices
    np.random.seed(fed_round)
    active_clients_inds = np.random.choice(selected_clients_inds, int((1-args.drop_rate) * m), replace=False)
    active_clients = [clients[i] for i in active_clients_inds]
    
    # Training 
    for client in active_clients:
        ClientUpdate(args, device, client)
        
    # Averaging 
    global_model = averageModels(global_model, active_clients)
    
    # Testing the average model
    test(args, global_model, device, global_test_loader, 'Global',True)
    test(args, global_model, device, global_train_loader, 'Global',False)
    # Share the global model with the clients
    for client in clients:
        client['model'].load_state_dict(global_model.state_dict())
        
if (args.save_model):
    torch.save(global_model.state_dict(), "FedAvg.pt")
# Out:
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/hook/hook.py:560: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   current_tensor = hook_self.torch.native_tensor(*args, **kwargs)
# /home/iiitd/.local/lib/python3.8/site-packages/syft/frameworks/torch/tensors/interpreters/native.py:156: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   to_return = self.native_grad
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.303588
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.494757
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.440894
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.340762
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.339608
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.328279
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.537373
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.487980
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.349624
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.345884
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 2.311100
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.442341
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.490997
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.500170
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.300523
#
# Test set: Average loss for Global model: 1.4560, Accuracy: 8670/10000 (87%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.471089
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.352778
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.293516
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.345986
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.224796
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.450482
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.269670
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.332320
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.338972
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.195185
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.487077
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.355561
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.382287
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.302627
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.262139
#
# Test set: Average loss for Global model: 1.3239, Accuracy: 8811/10000 (88%)
#
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.268099
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.385826
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.189708
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.310939
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.231497
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.296176
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.302199
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.276911
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.205350
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.234460
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.315708
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.326843
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.253833
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.165339
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.230083
#
# Test set: Average loss for Global model: 1.2634, Accuracy: 8898/10000 (89%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.245996
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.296722
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.273841
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.209637
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.173007
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.330438
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.333531
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.292348
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.174563
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.177720
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.287621
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.377814
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.292857
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.210186
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.310215
#
# Test set: Average loss for Global model: 1.2118, Accuracy: 8897/10000 (89%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.184200
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.266955
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.338324
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.209987
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.270239
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.229429
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.343872
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.265575
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.186711
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.214919
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.173730
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.350129
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.300605
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.214734
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.213614
#
# Test set: Average loss for Global model: 1.1996, Accuracy: 8882/10000 (89%)
#
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.163027
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.319665
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.246256
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.198142
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.211109
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.163591
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.200657
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.285977
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.243630
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.185020
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.176891
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.351949
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.297771
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.218102
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.218374
#
# Test set: Average loss for Global model: 1.1796, Accuracy: 8990/10000 (90%)
#
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.175283
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.382446
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.208094
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.194663
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.153179
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.199344
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.330967
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.214872
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.236837
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.178053
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.195689
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.250349
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.222988
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.116074
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.214923
#
# Test set: Average loss for Global model: 1.1809, Accuracy: 8926/10000 (89%)
#
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.159709
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.281127
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.271141
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.181660
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.272982
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.153472
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.203692
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.246569
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.209341
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.217246
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.141219
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.312951
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.227371
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.337713
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.186465
#
# Test set: Average loss for Global model: 1.1712, Accuracy: 9017/10000 (90%)
#
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.189737
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.311606
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.347098
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.287808
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.140996
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.109715
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.266730
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.202184
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.222721
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.174428
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.112712
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.407513
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.369833
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.214755
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.133527
#
# Test set: Average loss for Global model: 1.1480, Accuracy: 8977/10000 (90%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.062408
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.176763
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.198527
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.249197
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.176929
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.158771
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.247502
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.199101
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.192564
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.193170
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.123009
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.182733
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.209096
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.139808
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.122801
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.207669
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.219873
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.156906
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.131283
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.092301
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.271226
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.230152
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.242470
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.180290
#
# Test set: Average loss for Global model: 1.0813, Accuracy: 9013/10000 (90%)
#
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.061913
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.260517
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.209888
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.175458
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.167525
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.050978
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.304585
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.173317
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.203838
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.266201
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.097875
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.229184
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.129740
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.209537
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.244744
#
# Test set: Average loss for Global model: 1.0510, Accuracy: 9081/10000 (91%)
#
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.053946
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.212272
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.182960
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.218949
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.234732
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.015348
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.209395
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.322712
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.279463
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.169182
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.048990
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.275375
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.231642
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.255583
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.180585
#
# Test set: Average loss for Global model: 1.0690, Accuracy: 9043/10000 (90%)
#
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.068151
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.353882
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.222885
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.205075
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.364992
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.077563
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.189919
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.210176
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.206764
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.175353
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.040490
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.288408
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.207112
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.183262
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.102774
#
# Test set: Average loss for Global model: 1.0456, Accuracy: 9024/10000 (90%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.061312
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.237164
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.241336
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.184992
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.169781
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.028087
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.373622
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.241359
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.138856
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.186818
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.058899
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.208674
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.196947
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.116449
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.162092
#
# Test set: Average loss for Global model: 1.0822, Accuracy: 8987/10000 (90%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.086764
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.220341
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.230633
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.166359
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.248758
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.102998
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.269790
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.236175
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.229287
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.137106
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.005684
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.249208
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.213171
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.198439
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.156157
#
# Test set: Average loss for Global model: 1.0450, Accuracy: 9044/10000 (90%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.031414
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.242670
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.199659
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.144617
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.144188
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.011216
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.290464
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.177218
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.163440
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.147168
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.029294
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.225443
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.212656
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.230074
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.155411
#
# Test set: Average loss for Global model: 1.0948, Accuracy: 9059/10000 (91%)
#
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.100240
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.348479
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.241545
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.228548
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.297584
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.067412
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.255728
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.171751
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.224786
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.147970
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.098753
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.190486
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.173507
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.332686
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.274125
#
# Test set: Average loss for Global model: 1.0744, Accuracy: 9019/10000 (90%)
#
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.100113
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.359711
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.214260
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.206622
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.094994
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.022372
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.362466
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.304906
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.208711
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.229371
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.032038
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.222627
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.208499
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.203934
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.190892
#
# Test set: Average loss for Global model: 1.0997, Accuracy: 8985/10000 (90%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.109514
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.204830
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.188150
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.292197
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.152481
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.105364
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.203888
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.216714
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.182352
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.309515
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.080377
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.237367
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.337800
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.233387
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.123201
#
# Test set: Average loss for Global model: 1.1100, Accuracy: 9052/10000 (91%)
#
# Model client1 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.102683
# Model client1 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.223108
# Model client1 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.237795
# Model client1 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.165851
# Model client1 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.152533
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.079431
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.209007
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.228166
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.182268
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.188832
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.105059
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.208950
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.217127
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.189626
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.159423
#
# Test set: Average loss for Global model: 1.0505, Accuracy: 9052/10000 (91%)
#
# Model client2 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.062715
# Model client2 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.331472
# Model client2 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.198827
# Model client2 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.184161
# Model client2 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.296014
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 0.979506
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.209991
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.240508
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.143113
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.163231
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.022473
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.262714
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.270735
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.137242
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.139602
#
# Test set: Average loss for Global model: 1.1426, Accuracy: 9023/10000 (90%)
#
# Model client5 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.124949
# Model client5 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.233717
# Model client5 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.184591
# Model client5 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.107990
# Model client5 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.145341
# Model client3 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.143255
# Model client3 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.203366
# Model client3 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.186509
# Model client3 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.132419
# Model client3 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.145416
# Model client4 Train Epoch: 1 [0/12032 (0%)]	Loss: 1.148918
# Model client4 Train Epoch: 2 [0/12032 (0%)]	Loss: 0.234614
# Model client4 Train Epoch: 3 [0/12032 (0%)]	Loss: 0.200663
# Model client4 Train Epoch: 4 [0/12032 (0%)]	Loss: 0.216525
# Model client4 Train Epoch: 5 [0/12032 (0%)]	Loss: 0.118569
#
# Test set: Average loss for Global model: 1.0733, Accuracy: 9052/10000 (91%)

# %%
train_loss, test_loss
# Out:
# ([1.4489183291117351,
#   1.3147098028818767,
#   1.253915163675944,
#   1.2012592283884684,
#   1.188731842549642,
#   1.168264548110962,
#   1.170071420542399,
#   1.1600374759674073,
#   1.1368795247395833,
#   1.1335091125488281,
#   1.0901879288991292,
#   1.1316636287689208,
#   1.1082607758839924,
#   1.1132725503285725,
#   1.1380045004526773,
#   1.1008274383544923,
#   1.1004274487813315,
#   1.0761584710439047,
#   1.117350691350301,
#   1.091252066040039,
#   1.0794424282073976,
#   1.081229476292928,
#   1.1160388399759928,
#   1.0973325199127197,
#   1.0658118012746176,
#   1.1082851641337077,
#   1.0846132673899334,
#   1.0718695593516032,
#   1.0652637860616048,
#   1.0715046696980794,
#   1.0678856788635254,
#   1.0961485560099284,
#   1.047236520131429,
#   1.0698381685892742,
#   1.088001024246216,
#   1.0757266638437908,
#   1.0622573505401611,
#   1.0827289302825929,
#   1.077731437810262,
#   1.0992659351348877,
#   1.081123583730062,
#   1.0335109034220378,
#   1.1226092784881592,
#   1.0521324303944906,
#   1.0280480575561524,
#   1.0659087271372478,
#   1.0471377292633057,
#   1.0574469159444173,
#   1.0450193419138591,
#   1.0542960950215658,
#   1.0251468655904135,
#   0.995349957148234,
#   1.0971312615712483,
#   1.091938595199585,
#   1.0980597040812174,
#   1.0432459237416585,
#   1.1031821935017903,
#   1.0354115398406982,
#   1.084134408823649,
#   1.095765923055013,
#   1.0637117003122964,
#   1.0536305497487386,
#   1.0721634657541912,
#   1.1230367354075115,
#   1.0768044366200764,
#   1.0370620031992595,
#   1.05333730913798,
#   1.063967976506551,
#   1.0707440097808838,
#   1.0279995911916098,
#   1.0672747617085774,
#   1.0565172234853109,
#   1.0193229525248209,
#   1.028800396601359,
#   1.1108635664621989,
#   1.0501706882476807,
#   1.0342498605092367,
#   1.1079550543467205,
#   1.0756664052327474,
#   1.072114856338501,
#   1.049469176228841,
#   1.0889583983103435,
#   1.0562542078653971,
#   1.0453284898122153,
#   1.0890799374898275,
#   1.0673616466522218,
#   1.107131398264567,
#   1.0680118157704672,
#   1.036739297612508,
#   1.0550195870717367,
#   1.0318038909912108,
#   1.0689114966074627,
#   1.0308637882232665,
#   1.0821849689483642,
#   1.0603903013865152,
#   1.0866919175465901,
#   1.0971952709197998,
#   1.0355378932952881,
#   1.1299504919687906,
#   1.0595059389750163],
#  [1.455975485610962,
#   1.3239334339141846,
#   1.2633713954925536,
#   1.2118273193359375,
#   1.1996050817489623,
#   1.179641816520691,
#   1.1809255849838256,
#   1.1711785732269286,
#   1.147976797103882,
#   1.1450639116287231,
#   1.1021888357162475,
#   1.143060593032837,
#   1.1202423570632936,
#   1.1257915634155273,
#   1.1493579904556275,
#   1.1135239540100097,
#   1.1130386011123656,
#   1.0886717346191406,
#   1.1291916915893554,
#   1.1043123733520508,
#   1.0921055494308471,
#   1.0939094646453857,
#   1.1279577676773072,
#   1.110028596687317,
#   1.0785700656890869,
#   1.1209912061691285,
#   1.0971328548431396,
#   1.0851412982940674,
#   1.078364879989624,
#   1.0849229902267457,
#   1.0801909700393677,
#   1.1096317264556885,
#   1.0605921622276306,
#   1.083158927154541,
#   1.1009162475585939,
#   1.0882821263313294,
#   1.0747553133010865,
#   1.0950780729293823,
#   1.0912291612625122,
#   1.1117988027572632,
#   1.0935912273406982,
#   1.047290834236145,
#   1.1345107583999634,
#   1.065065509223938,
#   1.0415880319595336,
#   1.0787252599716186,
#   1.0604477584838867,
#   1.071056516647339,
#   1.0588763298034667,
#   1.068609718132019,
#   1.0392386472702027,
#   1.0094227274894714,
#   1.1099454881668092,
#   1.1049713373184205,
#   1.1104212146759034,
#   1.0563200400352477,
#   1.1162343948364257,
#   1.0493631740570069,
#   1.0967448055267335,
#   1.1086436721801758,
#   1.0762230920791627,
#   1.0671608201980591,
#   1.0849386795043945,
#   1.135667866897583,
#   1.0899520477294922,
#   1.050827038383484,
#   1.0671071489334107,
#   1.0764659677505493,
#   1.0840156436920165,
#   1.0422498664855957,
#   1.0812948797225952,
#   1.069077502822876,
#   1.0328351415634156,
#   1.0433358489990234,
#   1.1236702234268188,
#   1.0645899383544921,
#   1.0476269790649415,
#   1.1197957162857055,
#   1.089173797225952,
#   1.0856215880393982,
#   1.0637383501052857,
#   1.101237317085266,
#   1.070052872276306,
#   1.059468613052368,
#   1.1021440986633302,
#   1.0807060550689698,
#   1.119451456642151,
#   1.08132061958313,
#   1.0509766849517823,
#   1.0689828102111816,
#   1.0455529048919678,
#   1.0821628927230835,
#   1.0449569133758545,
#   1.0947960668563843,
#   1.0743715196609498,
#   1.0997225130081176,
#   1.109969722557068,
#   1.0504662242889404,
#   1.1425609146118163,
#   1.073294639968872])

# %%
print(np.multiply(test_acc,100))
# Out:
# [86.7  88.11 88.98 88.97 88.82 89.9  89.26 90.17 89.77 89.11 89.9  89.76
#  90.16 90.01 89.41 90.25 90.08 90.31 89.28 90.57 90.   90.32 90.46 89.9
#  90.31 90.57 90.49 90.19 89.95 90.05 90.5  90.06 89.97 90.19 90.15 89.91
#  90.08 89.62 89.89 90.45 90.11 90.16 90.35 90.24 90.32 89.99 90.41 89.92
#  89.88 90.53 90.07 89.64 90.21 90.22 89.81 90.31 90.33 90.47 89.82 90.26
#  90.1  90.37 90.27 90.17 90.71 89.47 89.71 90.4  90.04 90.38 89.51 90.08
#  89.9  89.11 90.47 90.68 90.29 89.8  89.85 90.35 89.98 90.57 89.93 90.16
#  90.45 89.93 90.55 90.13 90.81 90.43 90.24 89.87 90.44 90.59 90.19 89.85
#  90.52 90.52 90.23 90.52]

# %%
x = [(i+1) for i in range(len(train_loss))]

# %%
import matplotlib.pyplot as plt

#plt.plot(x,train_loss)
#plt.plot(x,test_loss)
plt.plot(x,train_acc)
plt.plot(x,test_acc)
plt.show()
